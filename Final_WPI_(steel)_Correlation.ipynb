# %%
import pandas as pd

# Load the Excel file (update the path if needed)
df = pd.read_excel("WPI_Master-dataset.xlsx", sheet_name="Sheet1")

# Rename columns for clarity
df = df.rename(columns={
    "WPI (stainless)": "WPI_Stainless",
    "WPI (mild flat)": "WPI_MildFlat",
    "WPI (mild long)": "WPI_MildLong",
    "WPI (Crude Petroleum)": "WPI_CrudePetroleum",
    "WPI (Iron Ore)": "WPI_IronOre",
    "WPI (Coking Coal)": "WPI_CokingCoal",
    "WPI (non-ferrous metals)": "WPI_NonFerrous",
    "(IIP 24th col)": "IIP_Metals",
    "(IIP 25th col)": "IIP_Machinery",
    "Avg. USD/INR": "USD_INR",
    "Inflation Rate (%)": "InflationRate",
    "Crude Steel Prod (MnT)": "CrudeSteel_MnT",
    "Finished Steel Prod (MnT)": "FinishedSteel_MnT",
    "Import (MnT)": "Import_MnT",
    "Export (MnT)": "Export_MnT",
    "Consumption (MnT)": "Consumption_MnT",
    "(SHFE)": "SHFE",
    "(Mild Steel Futures)": "MildSteelFutures",
    "(WPI cement)": "WPI_Cement"
})

# Check renamed columns
print(df.columns.tolist())
# Out:
# ['Date', 'WPI_Stainless', 'WPI_MildFlat', 'WPI_MildLong', 'WPI_CrudePetroleum', 'WPI_IronOre', 'WPI_CokingCoal', 'WPI_NonFerrous', 'IIP_Metals', 'IIP_Machinery', 'Manufacturing PMI', 'USD_INR', 'InflationRate', 'CrudeSteel_MnT', 'FinishedSteel_MnT', 'Import_MnT', 'Export_MnT', 'Consumption_MnT', 'SHFE', 'MildSteelFutures', 'WPI_Cement']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute the correlation matrix (only for numeric columns)
corr_matrix = df.corr(numeric_only=True)

# Plot the full heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlation Matrix of All Numeric Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Define target WPI columns
targets = ["WPI_Stainless", "WPI_MildFlat", "WPI_MildLong"]

# Loop over each target and show sorted correlations
for target in targets:
    sorted_corr = corr_matrix[target].drop(target).sort_values(key=abs, ascending=False)
    print(f"\n🔍 Correlation of all features with {target} (sorted by absolute value):\n")
    print(sorted_corr.round(3))
# Out:
# 🔍 Correlation of all features with WPI_Stainless (sorted by absolute value):
#
# WPI_MildFlat          0.867
# WPI_MildLong          0.841
# USD_INR              -0.825
# Consumption_MnT      -0.803
# FinishedSteel_MnT    -0.783
# IIP_Metals           -0.760
# CrudeSteel_MnT       -0.738
# Manufacturing PMI    -0.623
# SHFE                 -0.601
# MildSteelFutures     -0.573
# WPI_CrudePetroleum    0.553
# InflationRate         0.508
# IIP_Machinery        -0.451
# Import_MnT           -0.443
# Export_MnT            0.419
# WPI_Cement            0.235
# WPI_NonFerrous       -0.099
# WPI_IronOre           0.051
# WPI_CokingCoal       -0.029
# Name: WPI_Stainless, dtype: float64
#
# 🔍 Correlation of all features with WPI_MildFlat (sorted by absolute value):
#
# USD_INR              -0.903
# WPI_MildLong          0.877
# WPI_Stainless         0.867
# IIP_Metals           -0.840
# SHFE                 -0.778
# Consumption_MnT      -0.759
# MildSteelFutures     -0.740
# FinishedSteel_MnT    -0.731
# CrudeSteel_MnT       -0.681
# Manufacturing PMI    -0.630
# WPI_CrudePetroleum    0.603
# InflationRate         0.597
# IIP_Machinery        -0.555
# Import_MnT           -0.480
# WPI_Cement            0.469
# Export_MnT            0.334
# WPI_NonFerrous       -0.291
# WPI_CokingCoal       -0.127
# WPI_IronOre          -0.036
# Name: WPI_MildFlat, dtype: float64
#
# 🔍 Correlation of all features with WPI_MildLong (sorted by absolute value):
#
# WPI_MildFlat          0.877
# WPI_Stainless         0.841
# IIP_Metals           -0.723
# USD_INR              -0.673
# Consumption_MnT      -0.650
# MildSteelFutures     -0.639
# WPI_CrudePetroleum    0.630
# SHFE                 -0.621
# CrudeSteel_MnT       -0.618
# FinishedSteel_MnT    -0.587
# Manufacturing PMI    -0.546
# InflationRate         0.546
# IIP_Machinery        -0.529
# Import_MnT           -0.478
# WPI_Cement            0.420
# Export_MnT            0.141
# WPI_NonFerrous       -0.121
# WPI_CokingCoal       -0.072
# WPI_IronOre          -0.055
# Name: WPI_MildLong, dtype: float64
